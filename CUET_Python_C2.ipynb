# %% [markdown]
# **Arithmatic** **Operators**
# ---

# %%
print(5+6)
print(4-2)
print(5*2)
print(10/2)
print(7//2)
print(9%2)
print(9**99)
# Out:
# 11
# 2
# 10
# 5.0
# 3
# 1
# 29512665430652752148753480226197736314359272517043832886063884637676943433478020332709411004889

# %%
a = 5
b = 6
print('Sum ', a+b)
print('Difference ', a-b)
print('Multiplication ', a*b)
print('Division ', a/b)
print('Float Division ', a//b)
print('Remainder ', a%b)
print('Power ', a**b)
# Out:
# Sum  11
# Difference  -1
# Multiplication  30
# Division  0.8333333333333334
# Float Division  0
# Remainder  5
# Power  15625

# %% [markdown]
# **Assignment Operator**

# %%
x = 5
y = 1
x+= y
print(x)
# Out:
# 6

# %%
x = 5
y = 1
x-= y
print(x)
# Out:
# 4

# %%
x = 5
y = 1
x*= y
print(x)
# Out:
# 5

# %%
x = 5
y = 1
x/= y
print(x)
# Out:
# 5.0

# %%
x = 5
y = 1
x//= y
print(x)
# Out:
# 5

# %%
x = 5
y = 1
x%= y
print(x)
# Out:
# 0

# %%
x = 5
y = 1
x**= y
print(x)
# Out:
# 5

# %% [markdown]
# **Comparison Operators**
# ---

# %%
a = 5
b = 6
print('a == b =', a==b)
print('a != b =', a!=b)
print('a > b =', a > b)
print('a < b =', a < b)
print('a >= b =',a >= b)
print('a <= b', a <= b)
# Out:
# a == b = False
# a != b = True
# a > b = False
# a < b = True
# a >= b = False
# a <= b True

# %% [markdown]
# **Logical Operators**
# ---

# %%
a = 5
print(a > 1 and a < 6)
print(a > 2 or a < 10000)
print(not(a > 4 and a < 9))
# Out:
# True
# True
# False

# %% [markdown]
# **Binary Operators**
# ---

# %%
a = 5
b = 4
print('a & b =', a & b)
# Out:
# a & b = 4

# %%
a = 5
print(a >> 1)
print(a << 1)
print(a >> 2)
print(a << 2)
# Out:
# 2
# 10
# 1
# 20

# %% [markdown]
# **Special Operators**
# ---

# %%
#identity operators
a = 10
b = 10
c = 3
print(a is b)
print(a is c)
print(a is not c)
# Out:
# True
# False
# True

# %%
#Membership Operator
message = 'Hello World'
print('H' in message)
print('hello' not in message)
# Out:
# True
# True

# %% [markdown]
# **assignment**

# %%
number = int(input("Enter a number: "))

is_greater_than_10 = number > 10
is_even = number % 2 == 0

is_both = is_greater_than_10 and is_even

print("Is the number both greater than 10 and even?", is_both)
# Out:
# Enter a number: 7
# Is the number both greater than 10 and even? False

# %%
year = int(input("Enter a year: "))

# A leap year is divisible by 4, but not by 100 unless it is also divisible by 400.
is_leap_year = (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

if is_leap_year:
  print(year, "is a leap year.")
else:
  print(year, "is not a leap year.")
# Out:
# Enter a year: 2000
# 2000 is a leap year.
