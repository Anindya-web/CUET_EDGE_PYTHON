# %% [markdown]
# INTRO

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
#division
print(6/2)
# Out:
# 3.0

# %%
print("PYTHONISTA")
# Out:
# PYTHONISTA

# %%
#variables
name ="Anindya"     # string value assigned
age = 24            #integer value assigned
height = 5.0        #float value assigned
is_student = True   #boolean value assigned
subject = "E.E.E."  #string value assigned
is_happy = False    #boolean value assigned

# %%
#type conversion
#implicit
#integer
integer = 123
float = 2.22
new_number = integer + float
#display new value resulting data type
print("Value:",new_number)
print(type(new_number))
#boolean
result = False - 23
print(result)
# Out:
# Value: 125.22
# <class 'float'>
# -23

# %%
#explict
#type casting
string = "123"
integer = 23
string = int(string)
result = string + integer
print(result)
# Out:
# 146

# %%
site_name = "google.com"
print(site_name)

#assigning a new value to site_name
site_name = "youtube.com"
print(site_name)
# Out:
# google.com
# youtube.com

# %%
#multiple assignment
a = 1
b= 3.3
c = "hello"
print(a,b,c)
# Out:
# 1 3.3 hello

# %%
#user input
name = input("Enter your name: ")
city = input("Enter your city name: ")
student = input("Are you a student: ")
print("Hello,",name)
print("I am from,",city)
print("I am a student?",student)
# Out:
# Enter your name: a
# Enter your city name: b
# Are you a student: n
# Hello, a
# I am from, b
# n I am a student?

# %%
#area of rectangle
width = input("Enter the width of the rectangle: ")
height = input("Enter the height of the rectangle: ")
area=width*height
print("The area of the rectangle is:",area)
# Out:
# Enter the width of the rectangle: 10
# Enter the height of the rectangle: 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-3b5df0e54fcc> in <cell line: 4>()
#       2 width = input("Enter the width of the rectangle: ")
#       3 height = input("Enter the height of the rectangle: ")
# ----> 4 area=width*height
#       5 print("The area of the rectangle is:",area)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
#area of rectangle
width = input("Enter the width of the rectangle: ")
#input function by default takes string value
height = input("Enter the height of the rectangle: ")
area=int(width)*int(height)
print("The area of the rectangle is:",area)
# Out:
# Enter the width of the rectangle: 12
# Enter the height of the rectangle: 12
# The area of the rectangle is: 144

# %%
#assignment_D1
del float
num1 = float(input("Enter the num1 value: "))
num2 = float(input("Enter the num2 value: "))
sum_result = num1 + num2
sub_result = num1 - num2
mul_result = num1 * num2
div_result = num1 / num2
print("sum_result :",sum_result)
print("sub_result :",sub_result)
print("mul_result :",mul_result)
print("div_result :",div_result)
# Out:
# Enter the num1 value: 10
# Enter the num2 value: 5
# sum_result : 15.0
# sub_result : 5.0
# mul_result : 50.0
# div_result : 2.0
