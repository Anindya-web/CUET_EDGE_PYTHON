# %% [markdown]
# **Conditional** **Logic**
# ---

# %%
#if statement

# %%
#if-else statement
x=int(input("Enter a value: "))
if x > 5:
  print("x is greater than 5")
else:
  print("x is less than or equal to 5")
# Out:
# Enter a value: 12
# x is greater than 5

# %%
#elif statement
x = 7
if x > 10:
  print("x is greater than 10")
elif x == 7:
  print("x is equal to 7")
else:
  print("x is less than 10 and not equal to 7")
# Out:
# x is equal to 7

# %%
#nested if statement
x = float(input("Enter a number: "))
if x > 0:
  if x %2==0:
    print("The value is even")
  else:
    print("The value is odd")
else:
  print("The value is negative")
# Out:
# Enter a number: 23
# The value is odd

# %%
#the eilf-else ladder
x = 5
if x > 10:
  print("x is greater than 10")
elif x > 5 :
  print("x is greater than 5 but lessthan or equal to 10")
elif x == 5:
  print("x is equal to 5")
else:
  print("x is less than 5")
# Out:
# x is equal to 5

# %%
#Ternary (Conditional) Operator
x = 10
y = 20
min_value = x if x < y else y
print(min_value)
num = 10
result = "even" if num% 2 == 0 else "odd"
print(result)
# Out:
# 10
# even

# %% [markdown]
# **Pass Statement**
# ---

# %%
x = 2
if x > 5:
  pass
else:
  print("x is not greater than 5")
# Out:
# x is not greater than 5

# %% [markdown]
# **Chained** **Conditionals**
# ---

# %% [markdown]
# **Assignment**
# ---

# %%
#STUDENT GRADE CALCULATOR
x = int(input("Enter your number: "))
if x < 0 or x > 100:
  print("Invalid score. Please enter a number between 0 and 100.")
elif 90 <= x < 100:
  print("Your Grade is A")
elif 80 <= x < 89:
  print("Your Grade is B")
elif 70 <= x < 79:
  print("Your Grade is C")
elif 60 <= x < 69:
  print("Your Grade is D")
else:
  print("Your Grade is F")
# Out:
# Enter your number: 90
# Your Grade is A

# %%
#BMI CALCULATOR
x = float(input("enter your weight in kg: "))
y = float(input("enter your height in mteres: "))
BMI = x/(y**2)
print("Your BMI is: ", BMI)
if BMI < 18.5:
  print("Underwight")
elif BMI >= 18.5 and BMI  <24.9:
  print("Normal Weight")
elif BMI >= 25 and BMI < 29.9:
  print("Overweight")
else:
  print("Obesity")
# Out:
# enter your weight in kg: 60
# enter your height in mteres: 1.524
# Your BMI is:  25.83338500010333
# Overweight
